# %% [markdown]
# # Non-parametric regression

# %% [markdown]
# We consider a regession model $Y=h(X)+E$ where $(X,Y)$ are the observations, $E$ is a gaussian noise and $h$ is the function we want to learn. We assume that $h$ is a continuous function such that $h(0)=0$ and that the support of the distribution of $X$ is included in $[0,1]$.
#
# We set $L(h)$ as the squared loss associated to the model (i.e $L(h) = \mathbb{E}(Y-h(X))^2$ ).
#
# We can thus compute the Malliavin Gradient of $L$ with respect to $h$ as: $$\nabla L (h) (.) = \mathbb{E}\Biggl[ 2(Y-h(X)) \min(.,X) \Biggr] .$$
#
# Theoretically, we have now all the tools to perform a simple stochastic gradient descent to learn $h$. The SGD update takes the form:
# $$ h(.) = h(.) - 2 \alpha (Y-h(X)) \min(.,X)$$
# where $\alpha$ is the stepsize. However, to implement this method, one has to discretize the interval $[0,1]$. So one may not be able to compute $h(X)$, unless the value of $X$ falls in the discretized interval.
#
# To avoid this problem, a first approach is to discretize the interval $[0,1]$ beforehand into $d$ and then choose the closest point to each value of $X$ in order to compute $h(X)$. A second approach is to use the sample $X$ itself to discretize $[0,1]$. Surely a compromise between these two approaches must be made with respect to the values of $d$ and $n$.
#
# Anyhow, we used here the squared loss which gradient can be easily computed. However, for general losses, one can imagine a gradient that is not explicitly known or too coslty to be computed. In this case, referring to Malliavin Calculus, one can compute an unbiased estimate of the gradient using only the loss itself:
# $$ \hat{\nabla L} (h) (.) = \frac{1}{\gamma} L(h(X)+ \gamma B_X) B(.) $$
# where $\gamma$ is a smoothing parameter.
#
# Therefore, we can now perform the gradient-free SGD:
# $$h(.) = h(.) -  \frac{\alpha}{\gamma} L(h(X)+ \gamma B_X) B(.) $$
#
# Computationally speaking, the same problem as before arises. Moreover, the tuning of the smoothing parameter $\gamma$ is crucial as the gradient-free descent can easily encounter infinite values.

# %%
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-99ba79ecbbfb> in <module>
# ----> 1 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.linalg import sqrtm
from tqdm import tqdm
from math import *
from sklearn import neighbors
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-fea57b3b6ebd> in <module>
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       4 from scipy.linalg import sqrtm
#       5 from tqdm import tqdm
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in <module>
#     903 # triggering resolution of _auto_backend_sentinel.
#     904 rcParamsDefault = _rc_params_in_file(
# --> 905     cbook._get_data_path("matplotlibrc"),
#     906     # Strip leading comment.
#     907     transform=lambda line: line[1:] if line.startswith("#") else line,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _get_data_path(*args)
#     478     ``*args`` specify a path relative to the base data path.
#     479     """
# --> 480     return Path(matplotlib.get_data_path(), *args)
# ...

# %% [markdown]
# ## 0. A Brownian Motion function

# %%
def brownian(T, N): #returns an array N x trials, each column is a Brownian motion on [0,T]
    #T : Total time.
    #N : Total points
    #trials
    dt = T / N  
    x = np.zeros(N)
    for i in range(N - 1):
        x[i + 1] = x[i] + sqrt(dt) * np.random.randn()
    return x

# %%
plt.plot(np.linspace(0,1,1000),brownian(1,1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1dde92d032fa> in <module>
# ----> 1 plt.plot(np.linspace(0,1,1000),brownian(1,1000))
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## I. First idea : Divide [0,1] into d points

# %% [markdown]
# ### I.1. Generating a sample, fixing the hyper parameters and the initial conditions

# %%
#Sample:
n = 1000 #sample size
X = np.random.triangular(0, 0.7, 1, size=n)
E = np.random.normal(0, 0.5, n)
Y = payoff(X) + E

# %%
#Hyperparameters----------
d = 1000 #partition of [0,1]
t = np.linspace(0,1,d)
T = n #iterations in SGD
alpha = 0.1 #stepsize

#Initial condition________
h = np.zeros(d) #initial condition
for i in range(0,d):
    h[i]=t[i]
grad = np.zeros(d) #inital grad

# %% [markdown]
# ### I.2. SGD using the Malliavin Gradient and comparison with Nearest Neighbor

# %%
#SGD
for i in tqdm(range(0,T)):
    given_value = X[i]
    a_list = t
    absolute_difference_function = lambda list_value : abs(list_value - given_value)
    closest_value = min(a_list, key=absolute_difference_function)
    index = np.where(a_list==closest_value)[0][0]
    for tt in range(0,d):
        grad[tt]  = 2*(h[index]-Y[i])*min(t[tt],X[i])
        h[tt] = h[tt] - alpha*grad[tt]
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 380.36it/s]

# %%
#Comparison with Nearest neighbor----------------------------------
# Nearest neighbor regression model
X = np.sort( np.random.triangular(0, 0.7, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = payoff(X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 0.5, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#Visual-------------------------------------------------------------
plt.title("n= "+str(n)+", d=1000")

plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, payoff(T), color='y', label='y=payoff(x)')
                                                            
plt.scatter(X,)
plt.plot(t, payoff(t),'y')
plt.plot(t,h,'r', label="NewGD")
plt.legend()
#plt.savefig('exp3.png')
plt.show()
# Out:
# <ipython-input-235-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
# <ipython-input-235-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))

# %% [markdown]
# ### I.3. Gradient-free SGD using Malliavin Calculus and comparison with Nearest Neighbor

# %%
#Sample------------------------------------
n = 100 #sample size
X = np.random.triangular(0, 0.7, 1, size=n)
E = np.random.normal(0, 0.5, n)
Y = np.sin(2*pi*X) + E

#Hyperparameters---------------------------
d = 1000 #partition
t = np.linspace(0,1,d)
T = n #iterations
alpha = 0.05 #stepsize
gamma = 1 #smoothing parameter
trials= 1 # #Brownian motions per update

#Initial condition-------------------------
hB = np.zeros(d) #initial condition
for i in range(0,d):
    hB[i]=t[i]
grad = np.zeros((d,trials), dtype=np.float128) #inital grad

# %%
#Gradient-free SGD
for i in tqdm(range(0,n)):
    B = brownian(1,d, trials)
    given_value = X[i]
    a_list = t
    absolute_difference_function = lambda list_value : abs(list_value - given_value)
    closest_value = min(a_list, key=absolute_difference_function)
    index = np.where(a_list==closest_value)[0][0]
    for tt in range(0,d):
        grad[tt,:]  = (1/gamma)*((hB[index] + gamma*B[index] - Y[i])*(hB[index] + gamma*B[index] - Y[i]))*B[tt]
        hB[tt] = hB[tt] - alpha*np.mean(grad[tt,:])
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 32.87it/s]

# %%
#Comparison with Nearest neighbor------------------------------------
# Nearest neighbor regression model
X = np.sort( np.random.triangular(0, 0.7, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = np.sin(2*pi*X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 0.5, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#Visual------------------------------------------------------------
plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, np.sin(2*pi*T), color='y', label='y=sin(2 pi x)')

plt.title("n=100, d=1000")

plt.scatter(X,Y)
plt.plot(t,np.sin(2*pi*t),'y')
plt.plot(t,hB,'r', label='Gradient-free')

plt.legend()
#plt.savefig('exp5-alpha=0.01-gamma=1.png')
plt.show()

# %% [markdown]
# As one can see, the Malliavin descent performs competitively, and as the sample size increases, performs better than the Nearest Neighbors Search.

# %% [markdown]
# ## II. Second idea: Use the sample itself to divide [0,1] into n points

# %% [markdown]
# ### II.1. Generating a sample, fixing the hyper parameters and the initial conditions

# %%
n = 100 #sample size
X = np.random.triangular(0, 0.7, 1, size=n)
E = np.random.normal(0, 0.5, n)
Y = np.sin(2*pi*X) + E
t = np.sort(X)

# %%
h = np.zeros(n) #initial condition
for i in range(0,n):
    h[i]=t[i]
grad = np.zeros(n) #inital grad
alpha = 0.1 #stepsize
#plt.plot(t,h,'r')

# %% [markdown]
# ### II.2. SGD using the Malliavin Gradient and comparison with Nearest Neighbor

# %%
#SGD
#R = np.zeros(T)
#meanR = np.zeros(T)
for i in tqdm(range(0,n)):
    index = np.where(t == X[i])[0][0]
    for tt in range(0,n):
        grad[tt]  = 2*(h[index]-Y[i])*min(t[tt],X[i])
        h[tt] = h[tt] - alpha*grad[tt]
                
    #R[i] = (Y[i]-h[index])**2  
    #Rtest[i] = (Ytest[i]-h[index])**2  
    #meanR[i] = abs(np.mean(R[0:i+1]) - 0.25)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 3129.89it/s]

# %%
#Visual
# #############Comparison with Nearest neighbor################################################################
# Nearest neighbor regression model
d= 100
X = np.sort( np.random.triangular(0, 0.7, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = np.sin(2*pi*X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 0.5, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#plt.subplot(2, 1,  1)
#plt.scatter(X, y, color='darkorange', label='data')
plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, np.sin(2*pi*T), color='y', label='y=sin(2 pi x)')
#plt.axis('tight')
plt.title("n=10000, d=1000")
#                                                                weights))
plt.scatter(X,Y)
plt.plot(t,np.sin(2*pi*t),'y')
plt.plot(t,h,'r', label="NewGD")
#plt.tight_layout()
plt.legend()
#plt.savefig('exp3-2.png')
plt.show()

# %% [markdown]
# ### II.3. Gradient-free SGD using Malliavin Calculus and comparison with Nearest Neighbor

# %%
n = 100 #sample size
X = np.random.triangular(0, 0.7, 1, size=n)
E = np.random.normal(0, 0.5, n)
Y = np.sin(2*pi*X) + E

t = np.sort(X)
T = n #iterations

# %%
#Gradient-free SGD
hB = np.zeros(n) #initial condition
for i in range(0,n):
    hB[i]=t[i]
trials= 1
gamma=1
alpha=0.1
grad = np.zeros((n,trials), dtype=np.float128) #all grad
meangrad = np.zeros(n) #average of grad over trials

#RB = np.zeros(n)
#meanRB = np.zeros(n)
#Rtest = np.zeros(T)
#meanRtest = np.zeros(T) 

for i in tqdm(range(0,n)):
    B = brownian(1,n, trials)
    index = np.where(t==X[i])[0][0]
    for tt in range(0,n):
        grad[tt,:]  = (1/gamma)*((hB[index] + gamma*B[index] - Y[i])*(hB[index] + gamma*B[index] - Y[i]))*B[tt]
        hB[tt] = hB[tt] - alpha*np.mean(grad[tt,:])
        #meangrad = np.mean(grad[tt,:])
        #hB[tt] = hB[tt] - alpha*meangrad
        #print(B[tt])
    #meangrad = np.mean(grad,1)
    #print(meangrad)
    #for tt in range(0,n):
    #    hB[tt] = hB[tt] - alpha*meangrad[tt]
           
    #RB[i] = (Y[i]-h[index])**2  
    #Rtest[i] = (Ytest[i]-h[index])**2  
    #meanRB[i] = abs(np.mean(RB[0:i+1]) - 0.25)
    #meanRtest[i] = abs(np.mean(Rtest[0:i+1]) - 0.25)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 294.21it/s]

# %%
#Visual
# #############Comparison with Nearest neighbor################################################################
# Nearest neighbor regression model
X = np.sort( np.random.triangular(0, 0.7, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = np.sin(2*pi*X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 0.5, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#plt.subplot(2, 1,  1)
#plt.scatter(X, y, color='darkorange', label='data')
plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, np.sin(2*pi*T), color='y', label='y=sin(2 pi x)')
#plt.axis('tight')
plt.title("n=1000, d=1000")
#     
plt.scatter(X,Y)
plt.plot(t,np.sin(2*pi*t),'y')
plt.plot(t,hB,'r', label='Gradient-free')
#plt.plot(t,h,'r')
plt.legend()
#plt.savefig('exp6-2-alpha=0.01-gamma=1.png')
plt.show()

# %% [markdown]
# ## III. True Descent

# %%
import copy
#Sample:
n = 100 #sample size
X = np.random.triangular(0, 0.7, 1, size=n)
E = np.random.normal(0, 0.5, n)
Y = np.sin(2*pi*X) + E

# %%
#Hyperparameters----------
T = n #iterations in SGD
alpha = 0.1 #stepsize

# %%
nb_iter=[]
def new_f(old_f,Xobs,Yobs,alpha):
    nb_iter.append(1)
    oldfx,oldfxobs=old_f(0),old_f(1)
    return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)

# %%
def f_0(x):
    return 0
list_of_functions = [f_0]
#SGD
for i in tqdm(range(0,30)):
    old_f = copy.deepcopy(list_of_functions[i])
    list_of_functions.append(new_f(old_f,X[i],Y[i],alpha))
# Out:
#  90%|█████████ | 27/30 [06:32<00:43, 14.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-aa23d5923213> in <module>
#       5 for i in tqdm(range(0,30)):
#       6     old_f = copy.deepcopy(list_of_functions[i])
# ----> 7     list_of_functions.append(new_f(old_f,X[i],Y[i],alpha))
#       8
#
# <ipython-input-28-43250fcc93c8> in new_f(old_f, Xobs, Yobs, alpha)
#       2 def new_f(old_f,Xobs,Yobs,alpha):
#       3     nb_iter.append(1)
# ----> 4     oldfx,oldfxobs=old_f(0),old_f(1)
#       5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
# ...

# %%
g = list_of_functions[-1]

# %%
from time import time
t0=time()
g(1.02040816)
print("Cela a pris ",time()-t0," et cela a fait ",len(nb_iter))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-1d02b36072bc> in <module>
#       1 from time import time
#       2 t0=time()
# ----> 3 g(1.02040816)
#       4 print("Cela a pris ",time()-t0," et cela a fait ",len(nb_iter))
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
# ...

# %%
t = np.linspace(0,1,50)
predict = []
for x in tqdm(t):
    predict += [g(x)]
#predict
# Out:
#   0%|          | 0/50 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-03655e412b6b> in <module>
#       2 predict = []
#       3 for x in tqdm(t):
# ----> 4     predict += [g(x)]
#       5 #predict
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# <ipython-input-28-43250fcc93c8> in <lambda>(x)
#       3     nb_iter.append(1)
#       4     oldfx,oldfxobs=old_f(0),old_f(1)
# ----> 5     return lambda x: old_f(x)- 2 * alpha * (old_f(Xobs)-Yobs) * min(x,Xobs)
#
# ...

# %%
plt.plot(t,predict, 'r')
plt.plot(t, np.sin(2*pi*t))

# %% [markdown]
# ## IV. Raising the dimension (d=2)

# %%
n = 500 #sample size
dim = 2 #dimension
X = np.random.triangular(0, 0.7,1, (dim,n))
E = np.random.normal(0, 0.5, n)
Y =   np.sin(2*pi*X[0])*np.sin(2*pi*X[1]) + E

# %%
d = 100 #partition
t1 = np.sort(X[0])
t2 = np.sort(X[1])
T = n #iterations
h = np.zeros((n,n)) #initial condition
grad = np.zeros((n,n)) #inital grad
alpha = 0.1 #stepsize

# %%
#SGD
#predict = []
train = np.zeros(T)
for i in tqdm(range(0,T)):
    index0 = np.where(t1 == X[0][i])[0][0]
    index1 = np.where(t2 == X[1][i])[0][0]
    #predict += [h] 
    #print(predict[i])
    for tt in range(0,n):
        for ss in range(0,n):
            grad[tt,ss]  = 2*(h[index0,index1]-Y[i])*min(t1[tt],X[0][i])*min(t2[ss],X[1][i]) #pb bcz when tt=0, =0
            h[tt,ss] = h[tt,ss] - alpha*grad[tt,ss]  
            
    f = np.zeros(n)
    for j in range(0,n):
        index0 = np.where(t1 == X[0][j])[0][0]
        index1 = np.where(t2 == X[1][j])[0][0]
        f[j] = h[index0,index1]
    train[i] =  np.mean((Y-f)**2)
# Out:
# 100%|██████████| 500/500 [06:42<00:00,  1.24it/s]

# %%
plt.plot(np.linspace(0,n,n),abs(train-0.25), label='excess risk')   
plt.legend()
plt.savefig('trainloss-dim=2.png')

# %% [markdown]
# ## V. Black-Scholes

# %%
import scipy
from scipy import stats
import numpy as np

cdf = stats.norm(0, 1).cdf


def d1(S, K, T, r, sigma):
    return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))


def d2(S, K, T, r, sigma):
    return d1(S, K, T, r, sigma) - sigma * np.sqrt(T)



def call(S, K, T, r, sigma):
    return S * cdf(d1(S, K, T, r, sigma)) - K * np.exp(-r * T) * cdf(d2(S, K, T, r, sigma))

S = 100
TT = 1
K = 100
r = 0.05
Sigma = 10
a = call(S, K, TT, r, 0.2*Sigma)
b = call(S, K, TT, r, 0.8*Sigma)
def payoff(sigma):
    #if sigma < 0.2:
    #    return (a/0.2)*(sigma)
    #if sigma > 0.8:
    #    return b
    #else:
    return call(S,K,TT,r,sigma*Sigma)

# %%
t=np.linspace(0,1,1000)
plt.plot(t, payoff(t) )
# Out:
# <ipython-input-19-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))

# %%
def f0(sigma):
        return sigma

# %%
#Sample:
n = 1000 #sample size
X = np.random.triangular(0, 0.3, 1, size=n)
E = np.random.normal(0, 10, n)
Y = payoff(X) + E
step = 0.05

# %%
plt.scatter(X,Y)

# %%
F = np.zeros((n,n))
for j in range(n):
    F[0,j] = f0(X[j])
F2 = np.zeros((n,n))
B = brownian(1,10000)
indexB = np.zeros(n)
for i in range(n):
    for j in range(n):
        F[i,j] = F[i-1,j] -2*step*(F[i-1,i-1] - Y[i-1])*min(X[i-1],X[j])

# %%
d = 1000
t = np.linspace(0,1,1000)
L = np.zeros(d)
for i in range(d):
    Sum = [2*step*(F[j,j]-Y[j])*min(X[j],t[i]) for j in range(n)]
    Sum = sum(Sum)
    L[i] = f0(t[i]) - Sum

# %%
plt.plot(t,L)
X = np.sort( np.random.triangular(0, 0.3, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = payoff(X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 10, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#Visual-------------------------------------------------------------
plt.title("n= "+str(n)+", d=1000")

plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, payoff(T), color='y', label='y=payoff(x)')
# Out:
# <ipython-input-19-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
# <ipython-input-19-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))

# %%
X = np.sort( np.random.triangular(0, 0.7, 1, size=(n,1)), axis=0)
T = np.linspace(0, 1, d)[:, np.newaxis]
y = payoff(X)
y = y.ravel()

# Add noise to targets
y += 1 * np.random.normal(0, 2, n)

n_neighbors = 5

weights ='distance'
knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
y_ = knn.fit(X, y).predict(T)

#Visual-------------------------------------------------------------
plt.title("n= "+str(n)+", d=1000")

plt.plot(T, y_, label='NNS', color='g')
plt.plot(T, payoff(T), color='y', label='y=payoff(x)')
# Out:
# <ipython-input-25-87d63e5d87ac>:9: RuntimeWarning: divide by zero encountered in true_divide
#   return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
